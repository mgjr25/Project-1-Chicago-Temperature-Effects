# %%
# Dependencies
import requests
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import timezone
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# Import API key
import api_keys
from sodapy import Socrata

# %%
traffic_data = pd.read_csv('DataSets/TrafficData.csv')
traffic_data.head()
# Out:
#           day  maximum_fare  minimum_fare  avg_fare  std_dev_fare  rides
# 0  2013-01-01      910025.0           0.0   1377.74      13320.48  56953
# 1  2013-01-02      900054.0           0.0   1237.99       8560.35  36830
# 2  2013-01-03      800130.0           0.0   1233.54      10208.86  38808
# 3  2013-01-04      600046.0           0.0   1043.77       3515.89  50391
# 4  2013-01-05      300112.0           0.0   1006.10       1779.21  48354

# %%
traffic_data['day']=pd.to_datetime(traffic_data['day'])

# %%
weather_data_frame=pd.read_csv('DataSets/2016_weather.csv')
avg_temp_data_frame = weather_data_frame[weather_data_frame['element']=='TAVG']
avg_temp_data_frame['value']= pd.to_numeric( avg_temp_data_frame['value']/10)
avg_temp_data_frame
# Out:
# C:\Users\chami\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                id        date element  value mflag  qflag sflag  time
# 8     USW00094846    1/1/2016    TAVG   -4.8     H    NaN     S   NaN
# 21    USW00094846    1/2/2016    TAVG   -2.8     H    NaN     S   NaN
# 31    USW00094846    1/3/2016    TAVG   -2.9     H    NaN     S   NaN
# 40    USW00094846    1/4/2016    TAVG   -2.8     H    NaN     S   NaN
# 51    USW00094846    1/5/2016    TAVG   -3.6     H    NaN     S   NaN
# 65    USW00094846    1/6/2016    TAVG   -2.1     H    NaN     S   NaN
# 72    USW00094846    1/7/2016    TAVG    2.2     H    NaN     S   NaN
# 79    USW00094846    1/8/2016    TAVG    3.6     H    NaN     S   NaN
# 98    USW00094846    1/9/2016    TAVG    2.8     H    NaN     S   NaN
# 114   USW00094846   1/10/2016    TAVG   -7.2     H    NaN     S   NaN
# 120   USW00094846   1/11/2016    TAVG  -14.9     H    NaN     S   NaN
# 141   USW00094846   1/12/2016    TAVG  -10.0     H    NaN     S   NaN
# 146   USW00094846   1/13/2016    TAVG  -14.1     H    NaN     S   NaN
# 159   USW00094846   1/14/2016    TAVG   -0.8     H    NaN     S   NaN
# 170   USW00094846   1/15/2016    TAVG    4.4     H    NaN     S   NaN
# 183   USW00094846   1/16/2016    TAVG   -2.0     H    NaN     S   NaN
# 193   USW00094846   1/17/2016    TAVG  -13.6     H    NaN     S   NaN
# 208   USW00094846   1/18/2016    TAVG  -17.4     H    NaN     S   NaN
# 210   USW00094846   1/19/2016    TAVG  -14.6     H    NaN     S   NaN
# 232   USW00094846   1/20/2016    TAVG   -8.5     H    NaN     S   NaN
# 245   USW00094846   1/21/2016    TAVG   -7.2     H    NaN     S   NaN
# 252   USW00094846   1/22/2016    TAVG   -4.6     H    NaN     S   NaN
# 261   USW00094846   1/23/2016    TAVG   -2.3     H    NaN     S   NaN
# 274   USW00094846   1/24/2016    TAVG   -2.7     H    NaN     S   NaN
# 293   USW00094846   1/25/2016    TAVG   -0.8     H    NaN     S   NaN
# 298   USW00094846   1/26/2016    TAVG    0.4     H    NaN     S   NaN
# 316   USW00094846   1/27/2016    TAVG   -2.4     H    NaN     S   NaN
# 318   USW00094846   1/28/2016    TAVG    1.2     H    NaN     S   NaN
# 336   USW00094846   1/29/2016    TAVG   -2.1     H    NaN     S   NaN
# 343   USW00094846   1/30/2016    TAVG    3.1     H    NaN     S   NaN
# ...           ...         ...     ...    ...   ...    ...   ...   ...
# 3968  USW00094846   12/2/2016    TAVG    3.0     H    NaN     S   NaN
# 3982  USW00094846   12/3/2016    TAVG    0.7     H    NaN     S   NaN
# 3992  USW00094846   12/4/2016    TAVG   -0.3     H    NaN     S   NaN
# 4000  USW00094846   12/5/2016    TAVG   -0.1     H    NaN     S   NaN
# 4016  USW00094846   12/6/2016    TAVG    0.5     H    NaN     S   NaN
# 4027  USW00094846   12/7/2016    TAVG   -3.2     H    NaN     S   NaN
# 4041  USW00094846   12/8/2016    TAVG   -5.9     H    NaN     S   NaN
# 4048  USW00094846   12/9/2016    TAVG   -5.1     H    NaN     S   NaN
# 4065  USW00094846  12/10/2016    TAVG   -6.6     H    NaN     S   NaN
# 4081  USW00094846  12/11/2016    TAVG   -3.3     H    NaN     S   NaN
# 4090  USW00094846  12/12/2016    TAVG   -3.8     H    NaN     S   NaN
# 4097  USW00094846  12/13/2016    TAVG   -9.4     H    NaN     S   NaN
# 4117  USW00094846  12/14/2016    TAVG  -12.4     H    NaN     S   NaN
# 4122  USW00094846  12/15/2016    TAVG  -15.6     H    NaN     S   NaN
# 4144  USW00094846  12/16/2016    TAVG  -11.3     H    NaN     S   NaN
# 4152  USW00094846  12/17/2016    TAVG   -6.4     H    NaN     S   NaN
# 4166  USW00094846  12/18/2016    TAVG  -11.5     H    NaN     S   NaN
# 4182  USW00094846  12/19/2016    TAVG  -18.1     H    NaN     S   NaN
# 4188  USW00094846  12/20/2016    TAVG   -6.9     H    NaN     S   NaN
# 4202  USW00094846  12/21/2016    TAVG   -3.3     H    NaN     S   NaN
# 4212  USW00094846  12/22/2016    TAVG    1.2     H    NaN     S   NaN
# 4229  USW00094846  12/23/2016    TAVG   -0.8     H    NaN     S   NaN
# 4235  USW00094846  12/24/2016    TAVG    1.6     H    NaN     S   NaN
# 4252  USW00094846  12/25/2016    TAVG    0.7     H    NaN     S   NaN
# 4264  USW00094846  12/26/2016    TAVG    7.3     H    NaN     S   NaN
# 4277  USW00094846  12/27/2016    TAVG   -2.2     H    NaN     S   NaN
# 4282  USW00094846  12/28/2016    TAVG   -1.3     H    NaN     S   NaN
# 4294  USW00094846  12/29/2016    TAVG    0.9     H    NaN     S   NaN
# 4304  USW00094846  12/30/2016    TAVG   -1.5     H    NaN     S   NaN
# 4318  USW00094846  12/31/2016    TAVG    1.9     H    NaN     S   NaN
#
# [366 rows x 8 columns]

# %%
#Convert to DateTimeColumns
avg_temp_data_frame['date']=pd.to_datetime(avg_temp_data_frame['date'])
avg_temp_data_frame.head()
# Out:
# C:\Users\chami\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              id       date element  value mflag  qflag sflag  time
# 8   USW00094846 2016-01-01    TAVG   -4.8     H    NaN     S   NaN
# 21  USW00094846 2016-01-02    TAVG   -2.8     H    NaN     S   NaN
# 31  USW00094846 2016-01-03    TAVG   -2.9     H    NaN     S   NaN
# 40  USW00094846 2016-01-04    TAVG   -2.8     H    NaN     S   NaN
# 51  USW00094846 2016-01-05    TAVG   -3.6     H    NaN     S   NaN

# %%
merged_data = pd.merge(traffic_data, avg_temp_data_frame, left_on='day', right_on='date')
merged_data
merged_data.rename(columns={'value': 'avg_temp'}, inplace=True)

# %%
merged_data.plot(x='day',y='rides',figsize=(15,7),title="Ride Counts between 2016 to 2017")

# %%
merged_data.plot(x='day',y='rides',figsize=(15,7),title="Ride Counts between 2016 to 2017")

# %%
merged_data.plot(x='day',y='avg_temp',figsize=(15,7),title="Temperature Fluctuation between 2016 to 2017")

# %%
plt.scatter(x=merged_data['avg_temp'],y=merged_data['rides'])
plt.title('Taxi Rides vs Temperature ')
plt.ylabel("Taxi Rides")
plt.xlabel("Temperature")
# Out:
# Text(0.5,0,'Temperature')

# %%
files_list = ['Divvy_Trips_2016_Q1','Divvy_Trips_2016_04','Divvy_Trips_2016_05','Divvy_Trips_2016_06','Divvy_Trips_2016_Q1','Divvy_Trips_2016_Q3','Divvy_Trips_2016_Q4']
